# %% [markdown]
# # Exploratory Data Analysis of banking variables for a Private Financial firm.

# %% [markdown]
# .

# %%
import numpy as np                 # for the 2-d matrices
import pandas as pd                # for the data frames
import matplotlib.pyplot as plt    #for data vizualizations 
import datetime as dt              # for the datetime data
import seaborn as sns              # for the visualizations

# %% [markdown]
# .

# %%
#Importing the data into python notebook
data = pd.read_csv("LoansData .csv")

# %%
data.head()     #head() displays the first 5-6 rows from the data.
# Out:
#    LoanID  Amount.Requested  Amount.Funded.By.Investors Interest.Rate  \
# 0       1           20000.0                     20000.0         8.90%
# 1       2           19200.0                     19200.0        12.12%
# 2       3           35000.0                     35000.0        21.98%
# 3       4           10000.0                      9975.0         9.99%
# 4       5           12000.0                     12000.0        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 0         6541.67    735-739               14.0                   14272.0
# 1         4583.33    715-719               12.0                   11140.0
# 2        11500.00    690-694               14.0                   21977.0
# 3         3833.33    695-699               10.0                    9346.0
# 4         3195.00    695-699               11.0                   14469.0
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %% [markdown]
# .

# %%
data.shape
# Out:
# (2500, 15)

# %% [markdown]
# There are 2500 records for 15 variables.

# %% [markdown]
# .

# %% [markdown]
# # EDA: Exploratory Data Analysis

# %% [markdown]
# **Step1: Variables names following the Naming Convention**

# %% [markdown]
# Always check if the variable names is following the Naming Convention

# %%
data.columns
# Out:
# Index(['LoanID', 'Amount.Requested', 'Amount.Funded.By.Investors',
#        'Interest.Rate', 'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio',
#        'State', 'Home.Ownership', 'Monthly.Income', 'FICO.Range',
#        'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#        'Inquiries.in.the.Last.6.Months', 'Employment.Length'],
#       dtype='object')

# %% [markdown]
# .

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount.Requested                2499 non-null   float64
#  2   Amount.Funded.By.Investors      2499 non-null   float64
#  3   Interest.Rate                   2498 non-null   object
#  4   Loan.Length                     2500 non-null   object
#  5   Loan.Purpose                    2500 non-null   object
#  6   Debt.To.Income.Ratio            2499 non-null   object
#  7   State                           2500 non-null   object
#  8   Home.Ownership                  2499 non-null   object
#  9   Monthly.Income                  2499 non-null   float64
#  10  FICO.Range                      2498 non-null   object
#  11  Open.CREDIT.Lines               2497 non-null   float64
#  12  Revolving.CREDIT.Balance        2497 non-null   float64
#  13  Inquiries.in.the.Last.6.Months  2497 non-null   float64
#  14  Employment.Length               2423 non-null   object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data.iloc[1:4,]
# Out:
#    LoanID  Amount.Requested  Amount.Funded.By.Investors Interest.Rate  \
# 1       2           19200.0                     19200.0        12.12%
# 2       3           35000.0                     35000.0        21.98%
# 3       4           10000.0                      9975.0         9.99%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
#
#    Monthly.Income FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 1         4583.33    715-719               12.0                   11140.0
# 2        11500.00    690-694               14.0                   21977.0
# 3         3833.33    695-699               10.0                    9346.0
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years

# %% [markdown]
# .

# %%
#Checking the shape of the data
data.shape #There are 2500 records and 15 variables available in the data.
# Out:
# (2500, 15)

# %% [markdown]
# .

# %%
data.head(2)
# Out:
#    LoanID  Amount.Requested  Amount.Funded.By.Investors Interest.Rate  \
# 0       1           20000.0                     20000.0         8.90%
# 1       2           19200.0                     19200.0        12.12%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
#
#    Monthly.Income FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 0         6541.67    735-739               14.0                   14272.0
# 1         4583.33    715-719               12.0                   11140.0
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years

# %% [markdown]
# .

# %%
data.columns  #attribute or features
# Out:
# Index(['LoanID', 'Amount.Requested', 'Amount.Funded.By.Investors',
#        'Interest.Rate', 'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio',
#        'State', 'Home.Ownership', 'Monthly.Income', 'FICO.Range',
#        'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#        'Inquiries.in.the.Last.6.Months', 'Employment.Length'],
#       dtype='object')

# %% [markdown]
# .

# %%
data.columns = [i.replace('.','_') for i in data.columns]  #list comprehensions

# %%
data.columns
# Out:
# Index(['LoanID', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Loan_Purpose', 'Debt_To_Income_Ratio',
#        'State', 'Home_Ownership', 'Monthly_Income', 'FICO_Range',
#        'Open_CREDIT_Lines', 'Revolving_CREDIT_Balance',
#        'Inquiries_in_the_Last_6_Months', 'Employment_Length'],
#       dtype='object')

# %% [markdown]
# .

# %% [markdown]
# **Step 2: Check the information: Data type Conversions**

# %%
data.head(2)
# Out:
#    LoanID  Amount_Requested  Amount_Funded_By_Investors Interest_Rate  \
# 0       1           20000.0                     20000.0         8.90%
# 1       2           19200.0                     19200.0        12.12%
#
#   Loan_Length        Loan_Purpose Debt_To_Income_Ratio State Home_Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
#
#    Monthly_Income FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         6541.67    735-739               14.0                   14272.0
# 1         4583.33    715-719               12.0                   11140.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years

# %% [markdown]
# .

# %%
data['Interest_Rate'] = data['Interest_Rate'].str.replace('%','').astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   object
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   object
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   object
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data['Employment_Length']
# Out:
# 0        < 1 year
# 1         2 years
# 2         2 years
# 3         5 years
# 4         9 years
#           ...
# 2495      8 years
# 2496    10+ years
# 2497    10+ years
# 2498      5 years
# 2499    10+ years
# Name: Employment_Length, Length: 2500, dtype: object

# %% [markdown]
# .

# %%
data['FICO_Range'].str.split('-',expand = True)
# Out:
#         0    1
# 0     735  739
# 1     715  719
# 2     690  694
# 3     695  699
# 4     695  699
# ...   ...  ...
# 2495  705  709
# 2496  740  744
# 2497  680  684
# 2498  675  679
# 2499  670  674
#
# [2500 rows x 2 columns]

# %% [markdown]
# .

# %%
data['FICO_Range'] = data['FICO_Range'].str.split('-',expand = True)[0].astype('float')

# %%
data.head()
# Out:
#    LoanID  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0       1           20000.0                     20000.0           8.90
# 1       2           19200.0                     19200.0          12.12
# 2       3           35000.0                     35000.0          21.98
# 3       4           10000.0                      9975.0           9.99
# 4       5           12000.0                     12000.0          11.71
#
#   Loan_Length        Loan_Purpose Debt_To_Income_Ratio State Home_Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly_Income  FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         6541.67       735.0               14.0                   14272.0
# 1         4583.33       715.0               12.0                   11140.0
# 2        11500.00       690.0               14.0                   21977.0
# 3         3833.33       695.0               10.0                    9346.0
# 4         3195.00       695.0               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %% [markdown]
# .

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   object
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   object
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   object
# dtypes: float64(8), int64(1), object(6)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %% [markdown]
# Average monthly income of the customers
# np.round(data.Monthly_Income.mean(),3)  #round is a function...numpy(np)

# %% [markdown]
# data.describe().round(2)# for descriptive analysis , we get the measures of central ten

# %% [markdown]
# .

# %% [markdown]
# # Data type conversions:

# %%
data.head(5)
# Out:
#    LoanID  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0       1           20000.0                     20000.0           8.90
# 1       2           19200.0                     19200.0          12.12
# 2       3           35000.0                     35000.0          21.98
# 3       4           10000.0                      9975.0           9.99
# 4       5           12000.0                     12000.0          11.71
#
#   Loan_Length        Loan_Purpose Debt_To_Income_Ratio State Home_Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly_Income  FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         6541.67       735.0               14.0                   14272.0
# 1         4583.33       715.0               12.0                   11140.0
# 2        11500.00       690.0               14.0                   21977.0
# 3         3833.33       695.0               10.0                    9346.0
# 4         3195.00       695.0               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %% [markdown]
# .

# %%
data.Employment_Length
# Out:
# 0        < 1 year
# 1         2 years
# 2         2 years
# 3         5 years
# 4         9 years
#           ...
# 2495      8 years
# 2496    10+ years
# 2497    10+ years
# 2498      5 years
# 2499    10+ years
# Name: Employment_Length, Length: 2500, dtype: object

# %% [markdown]
# .

# %%
data.info() #Checking if the datatypes of the variables are correct or not.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   object
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   object
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   object
# dtypes: float64(8), int64(1), object(6)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   object
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   object
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   object
# dtypes: float64(8), int64(1), object(6)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data['Loan_Length'] = data['Loan_Length'].str.replace('months','').astype('float')
data['Debt_To_Income_Ratio'] = data['Debt_To_Income_Ratio'].str.replace('%','').astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   float64
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   float64
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   object
# dtypes: float64(10), int64(1), object(4)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data.head()
# Out:
#    LoanID  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0       1           20000.0                     20000.0           8.90
# 1       2           19200.0                     19200.0          12.12
# 2       3           35000.0                     35000.0          21.98
# 3       4           10000.0                      9975.0           9.99
# 4       5           12000.0                     12000.0          11.71
#
#    Loan_Length        Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 0         36.0  debt_consolidation                 14.90    SC       MORTGAGE
# 1         36.0  debt_consolidation                 28.36    TX       MORTGAGE
# 2         60.0  debt_consolidation                 23.81    CA       MORTGAGE
# 3         36.0  debt_consolidation                 14.30    KS       MORTGAGE
# 4         36.0         credit_card                 18.78    NJ           RENT
#
#    Monthly_Income  FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         6541.67       735.0               14.0                   14272.0
# 1         4583.33       715.0               12.0                   11140.0
# 2        11500.00       690.0               14.0                   21977.0
# 3         3833.33       695.0               10.0                    9346.0
# 4         3195.00       695.0               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %% [markdown]
# .

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   float64
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   float64
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   object
# dtypes: float64(10), int64(1), object(4)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data.head()
# Out:
#    LoanID  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0       1           20000.0                     20000.0           8.90
# 1       2           19200.0                     19200.0          12.12
# 2       3           35000.0                     35000.0          21.98
# 3       4           10000.0                      9975.0           9.99
# 4       5           12000.0                     12000.0          11.71
#
#    Loan_Length        Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 0         36.0  debt_consolidation                 14.90    SC       MORTGAGE
# 1         36.0  debt_consolidation                 28.36    TX       MORTGAGE
# 2         60.0  debt_consolidation                 23.81    CA       MORTGAGE
# 3         36.0  debt_consolidation                 14.30    KS       MORTGAGE
# 4         36.0         credit_card                 18.78    NJ           RENT
#
#    Monthly_Income  FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         6541.67       735.0               14.0                   14272.0
# 1         4583.33       715.0               12.0                   11140.0
# 2        11500.00       690.0               14.0                   21977.0
# 3         3833.33       695.0               10.0                    9346.0
# 4         3195.00       695.0               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %% [markdown]
# .

# %%
data.Employment_Length
# Out:
# 0        < 1 year
# 1         2 years
# 2         2 years
# 3         5 years
# 4         9 years
#           ...
# 2495      8 years
# 2496    10+ years
# 2497    10+ years
# 2498      5 years
# 2499    10+ years
# Name: Employment_Length, Length: 2500, dtype: object

# %% [markdown]
# .

# %%
data.shape
# Out:
# (2500, 15)

# %%
data['Employment_Length'] = data['Employment_Length'].str.replace('years','').str.replace('year','').str.replace('<','').str.replace('+','').astype('float')

# %%
data.Employment_Length
# Out:
# 0        1.0
# 1        2.0
# 2        2.0
# 3        5.0
# 4        9.0
#         ...
# 2495     8.0
# 2496    10.0
# 2497    10.0
# 2498     5.0
# 2499    10.0
# Name: Employment_Length, Length: 2500, dtype: float64

# %% [markdown]
# .

# %% [markdown]
# # Checking the relevant and irrelevant variables in the first phase of EDA:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   float64
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   float64
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data.nunique()   # we will get cardinality of each column
# Out:
# LoanID                            2500
# Amount_Requested                   380
# Amount_Funded_By_Investors         710
# Interest_Rate                      275
# Loan_Length                          2
# Loan_Purpose                        14
# Debt_To_Income_Ratio              1669
# State                               46
# Home_Ownership                       5
# Monthly_Income                     632
# FICO_Range                          38
# Open_CREDIT_Lines                   29
# Revolving_CREDIT_Balance          2349
# Inquiries_in_the_Last_6_Months      10
# Employment_Length                   10
# dtype: int64

# %% [markdown]
# .

# %% [markdown]
# If there is any column with a cardinality of 1, Just drop it.
# data.drop(columns = ['Country','Pincode'], inplace  = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2498 non-null   float64
#  4   Loan_Length                     2500 non-null   float64
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2499 non-null   float64
#  7   State                           2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2499 non-null   float64
#  10  FICO_Range                      2498 non-null   float64
#  11  Open_CREDIT_Lines               2497 non-null   float64
#  12  Revolving_CREDIT_Balance        2497 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2497 non-null   float64
#  14  Employment_Length               2423 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 293.1+ KB

# %% [markdown]
# .

# %%
data['Loan_Length'].value_counts()  #Always checks the value counts of object variable.
# Out:
# Loan_Length
# 36.0    1952
# 60.0     548
# Name: count, dtype: int64

# %% [markdown]
# .

# %%
print(data['Loan_Length'].value_counts())
data['Loan_Length'].value_counts().plot(kind = 'bar',color = 'green')
plt.title("Distribution of customers by their loan lengths.")
plt.xlabel("Loan length")
plt.ylabel("No of customers")
# Out:
# Loan_Length
# 36.0    1952
# 60.0     548
# Name: count, dtype: int64
# Text(0, 0.5, 'No of customers')

# %% [markdown]
# .

# %% [markdown]
# # **Distribution of customers by State:**

# %%
print(data['State'].value_counts())
data['State'].value_counts().plot(kind = 'bar',color = 'yellow',figsize = (20,15))
plt.title("Distribution of customers by their State.")
plt.xlabel("States")
plt.ylabel("No of customers")
# Out:
# State
# CA    433
# NY    255
# TX    174
# FL    169
# IL    101
# GA     98
# PA     96
# NJ     94
# VA     78
# MA     73
# OH     71
# MD     68
# NC     64
# CO     61
# WA     58
# CT     50
# AZ     46
# MI     45
# MN     38
# AL     38
# MO     33
# NV     32
# OR     30
# SC     28
# WI     26
# KY     23
# LA     22
# OK     21
# KS     21
# UT     16
# NH     15
# RI     15
# WV     15
# NM     13
# AR     13
# HI     12
# AK     11
# DC     11
# DE      8
# MT      7
# VT      5
# SD      4
# WY      4
# IN      3
# IA      1
# MS      1
# Name: count, dtype: int64
# Text(0, 0.5, 'No of customers')

# %% [markdown]
# .

# %%
print(data['Loan_Purpose'].value_counts())
data['Loan_Purpose'].value_counts().plot(kind = 'bar',color = 'red',figsize = (15,10))
plt.title("Distribution of customers by their Loan_Purpose.")
plt.xlabel("Loan_Purpose")
plt.ylabel("No of customers")
# Out:
# Loan_Purpose
# debt_consolidation    1307
# credit_card            444
# other                  201
# home_improvement       152
# major_purchase         101
# small_business          87
# car                     50
# wedding                 39
# medical                 30
# moving                  29
# vacation                21
# house                   20
# educational             15
# renewable_energy         4
# Name: count, dtype: int64
# Text(0, 0.5, 'No of customers')

# %% [markdown]
# .

# %%
print(data['Home_Ownership'].value_counts())
data['Home_Ownership'].value_counts().plot(kind = 'bar',color = 'blue',figsize = (8,5))
plt.title("Distribution of customers by their Home_Ownership.")
plt.xlabel("Home_Ownership")
plt.ylabel("No of customers")
# Out:
# Home_Ownership
# MORTGAGE    1147
# RENT        1146
# OWN          200
# OTHER          5
# NONE           1
# Name: count, dtype: int64
# Text(0, 0.5, 'No of customers')

# %% [markdown]
# .

# %% [markdown]
# # Data Duplicacy: Chech if their is duplicate data or not: DDT ( Data Duplicacy Treatment)

# %%
#Check the data duplicacy:
data.duplicated().value_counts()
# Out:
# False    2500
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no data duplicacy in our data.

# %% [markdown]
# #0.05...5% data duplicacy.
# #data = data.drop_duplicates()

# %% [markdown]
# **How to rename the variables?**

# %%
data.columns
# Out:
# Index(['LoanID', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Loan_Purpose', 'Debt_To_Income_Ratio',
#        'State', 'Home_Ownership', 'Monthly_Income', 'FICO_Range',
#        'Open_CREDIT_Lines', 'Revolving_CREDIT_Balance',
#        'Inquiries_in_the_Last_6_Months', 'Employment_Length'],
#       dtype='object')

# %% [markdown]
# .

# %%
data = data.rename(columns = {'LoanID':'Loan_id','State':'States'})

# %%
data.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Loan_Purpose', 'Debt_To_Income_Ratio',
#        'States', 'Home_Ownership', 'Monthly_Income', 'FICO_Range',
#        'Open_CREDIT_Lines', 'Revolving_CREDIT_Balance',
#        'Inquiries_in_the_Last_6_Months', 'Employment_Length'],
#       dtype='object')

# %% [markdown]
# .

# %% [markdown]
# # Missing Values Treatment:

# %%
data.head()
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
# 2        3           35000.0                     35000.0          21.98
# 3        4           10000.0                      9975.0           9.99
# 4        5           12000.0                     12000.0          11.71
#
#    Loan_Length        Loan_Purpose  Debt_To_Income_Ratio States  \
# 0         36.0  debt_consolidation                 14.90     SC
# 1         36.0  debt_consolidation                 28.36     TX
# 2         60.0  debt_consolidation                 23.81     CA
# 3         36.0  debt_consolidation                 14.30     KS
# 4         36.0         credit_card                 18.78     NJ
#
#   Home_Ownership  Monthly_Income  FICO_Range  Open_CREDIT_Lines  \
# 0       MORTGAGE         6541.67       735.0               14.0
# 1       MORTGAGE         4583.33       715.0               12.0
# 2       MORTGAGE        11500.00       690.0               14.0
# 3       MORTGAGE         3833.33       695.0               10.0
# 4           RENT         3195.00       695.0               11.0
#
#    Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  Employment_Length
# 0                   14272.0                             2.0                1.0
# 1                   11140.0                             1.0                2.0
# 2                   21977.0                             1.0                2.0
# 3                    9346.0                             0.0                5.0
# 4                   14469.0                             0.0                9.0

# %%
data.Amount_Requested.isna().sum()
# Out:
# 1

# %%
data.shape
# Out:
# (2500, 15)

# %%
data.isna().sum()
# Out:
# Loan_id                            0
# Amount_Requested                   1
# Amount_Funded_By_Investors         1
# Interest_Rate                      2
# Loan_Length                        0
# Loan_Purpose                       0
# Debt_To_Income_Ratio               1
# States                             0
# Home_Ownership                     1
# Monthly_Income                     1
# FICO_Range                         2
# Open_CREDIT_Lines                  3
# Revolving_CREDIT_Balance           3
# Inquiries_in_the_Last_6_Months     3
# Employment_Length                 77
# dtype: int64

# %% [markdown]
# #(data.isna().sum()/data.shape[0])*100

# %% [markdown]
# .

# %% [markdown]
# We have the maximum of 3% values missing in the Employment length variable.

# %% [markdown]
# Creating a UDF which can automate the missing value treatment.

# %%
data.shape
# Out:
# (2500, 15)

# %%
data.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Loan_Purpose', 'Debt_To_Income_Ratio',
#        'States', 'Home_Ownership', 'Monthly_Income', 'FICO_Range',
#        'Open_CREDIT_Lines', 'Revolving_CREDIT_Balance',
#        'Inquiries_in_the_Last_6_Months', 'Employment_Length'],
#       dtype='object')

# %% [markdown]
# .

# %%
def miss_value_treat(s):
    if s.dtype == 'O':
        s = s.fillna(s.mode())
    else:
        s = s.fillna(s.median())
    return s

# %%
data = data.apply(miss_value_treat)

# %%
data.isna().sum()
# Out:
# Loan_id                           0
# Amount_Requested                  0
# Amount_Funded_By_Investors        0
# Interest_Rate                     0
# Loan_Length                       0
# Loan_Purpose                      0
# Debt_To_Income_Ratio              0
# States                            0
# Home_Ownership                    1
# Monthly_Income                    0
# FICO_Range                        0
# Open_CREDIT_Lines                 0
# Revolving_CREDIT_Balance          0
# Inquiries_in_the_Last_6_Months    0
# Employment_Length                 0
# dtype: int64

# %% [markdown]
# .

# %%
data['Amount_Requested'] = data.Amount_Requested.fillna(data['Amount_Requested'].median())

# %%
data['Amount_Funded_By_Investors'] = data.Amount_Funded_By_Investors.fillna(data['Amount_Funded_By_Investors'].median())

# %%
data.isna().sum()
# Out:
# Loan_id                           0
# Amount_Requested                  0
# Amount_Funded_By_Investors        0
# Interest_Rate                     0
# Loan_Length                       0
# Loan_Purpose                      0
# Debt_To_Income_Ratio              0
# States                            0
# Home_Ownership                    1
# Monthly_Income                    0
# FICO_Range                        0
# Open_CREDIT_Lines                 0
# Revolving_CREDIT_Balance          0
# Inquiries_in_the_Last_6_Months    0
# Employment_Length                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Loan_id                         2500 non-null   int64
#  1   Amount_Requested                2500 non-null   float64
#  2   Amount_Funded_By_Investors      2500 non-null   float64
#  3   Interest_Rate                   2500 non-null   float64
#  4   Loan_Length                     2500 non-null   float64
#  5   Loan_Purpose                    2500 non-null   object
#  6   Debt_To_Income_Ratio            2500 non-null   float64
#  7   States                          2500 non-null   object
#  8   Home_Ownership                  2499 non-null   object
#  9   Monthly_Income                  2500 non-null   float64
#  10  FICO_Range                      2500 non-null   float64
#  11  Open_CREDIT_Lines               2500 non-null   float64
#  12  Revolving_CREDIT_Balance        2500 non-null   float64
#  13  Inquiries_in_the_Last_6_Months  2500 non-null   float64
#  14  Employment_Length               2500 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 293.1+ KB

# %%
data.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Loan_Purpose', 'Debt_To_Income_Ratio',
#        'States', 'Home_Ownership', 'Monthly_Income', 'FICO_Range',
#        'Open_CREDIT_Lines', 'Revolving_CREDIT_Balance',
#        'Inquiries_in_the_Last_6_Months', 'Employment_Length'],
#       dtype='object')

# %% [markdown]
# .

# %% [markdown]
# # Separating the categorical Variables and Numerical variables into two different datasets for Data Preparations for Data Analysis

# %%
categorical = [var for var in data.columns if data[var].dtype == 'O']

# %%
categorical
# Out:
# ['Loan_Purpose', 'States', 'Home_Ownership']

# %%
cat_data = data[categorical]

# %%
cat_data['Loan_id'] = data['Loan_id']
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_1252\1913625421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['Loan_id'] = data['Loan_id']

# %%
cat_data
# Out:
#             Loan_Purpose States Home_Ownership  Loan_id
# 0     debt_consolidation     SC       MORTGAGE        1
# 1     debt_consolidation     TX       MORTGAGE        2
# 2     debt_consolidation     CA       MORTGAGE        3
# 3     debt_consolidation     KS       MORTGAGE        4
# 4            credit_card     NJ           RENT        5
# ...                  ...    ...            ...      ...
# 2495  debt_consolidation     NY       MORTGAGE     2496
# 2496    home_improvement     MD            OWN     2497
# 2497  debt_consolidation     PA       MORTGAGE     2498
# 2498      major_purchase     NJ           RENT     2499
# 2499  debt_consolidation     NY           RENT     2500
#
# [2500 rows x 4 columns]

# %%
cat_data.shape
# Out:
# (2500, 4)

# %%
numerical = [var for var in data.columns if data[var].dtype != 'O']

# %%
num_data = data[numerical]

# %%
num_data
# Out:
#       Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0           1           20000.0                    20000.00           8.90
# 1           2           19200.0                    19200.00          12.12
# 2           3           35000.0                    35000.00          21.98
# 3           4           10000.0                     9975.00           9.99
# 4           5           12000.0                    12000.00          11.71
# ...       ...               ...                         ...            ...
# 2495     2496           30000.0                    29950.00          16.77
# 2496     2497           16000.0                    16000.00          14.09
# 2497     2498           10000.0                    10000.00          13.99
# 2498     2499            6000.0                     6000.00          12.42
# 2499     2500            9000.0                     5242.75          13.79
#
#       Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0            36.0                 14.90         6541.67       735.0
# 1            36.0                 28.36         4583.33       715.0
# 2            60.0                 23.81        11500.00       690.0
# 3            36.0                 14.30         3833.33       695.0
# 4            36.0                 18.78         3195.00       695.0
# ...           ...                   ...             ...         ...
# 2495         60.0                 19.23         9250.00       705.0
# 2496         60.0                 21.54         8903.25       740.0
# 2497         36.0                  4.89         2166.67       680.0
# 2498         36.0                 16.66         3500.00       675.0
# 2499         36.0                  6.76         3875.00       670.0
#
#       Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0                  14.0                   14272.0
# 1                  12.0                   11140.0
# 2                  14.0                   21977.0
# 3                  10.0                    9346.0
# 4                  11.0                   14469.0
# ...                 ...                       ...
# 2495               15.0                   45880.0
# 2496               18.0                   18898.0
# 2497                4.0                    4544.0
# 2498                8.0                    7753.0
# 2499                7.0                    7589.0
#
#       Inquiries_in_the_Last_6_Months  Employment_Length
# 0                                2.0                1.0
# 1                                1.0                2.0
# 2                                1.0                2.0
# 3                                0.0                5.0
# 4                                0.0                9.0
# ...                              ...                ...
# 2495                             1.0                8.0
# 2496                             1.0               10.0
# 2497                             0.0               10.0
# 2498                             0.0                5.0
# 2499                             0.0               10.0
#
# [2500 rows x 12 columns]

# %% [markdown]
# .

# %% [markdown]
# # Filling missing values in Numerical data with the Median values.

# %%
for i in num_data.columns:
        num_data[i] = num_data[i].fillna(num_data[i].median())
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_1252\3523660906.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[i] = num_data[i].fillna(num_data[i].median())

# %%
num_data.isna().sum()
# Out:
# Loan_id                           0
# Amount_Requested                  0
# Amount_Funded_By_Investors        0
# Interest_Rate                     0
# Loan_Length                       0
# Debt_To_Income_Ratio              0
# Monthly_Income                    0
# FICO_Range                        0
# Open_CREDIT_Lines                 0
# Revolving_CREDIT_Balance          0
# Inquiries_in_the_Last_6_Months    0
# Employment_Length                 0
# dtype: int64

# %% [markdown]
# .

# %% [markdown]
# # Filling missing values in Categorical data with the Mode values

# %%
for i in cat_data.columns:
        cat_data[i] = cat_data[i].fillna(cat_data[i].mode())
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_1252\2803963677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data[i] = cat_data[i].fillna(cat_data[i].mode())

# %%
cat_data.isna().sum()
# Out:
# Loan_Purpose      0
# States            0
# Home_Ownership    1
# Loan_id           0
# dtype: int64

# %%
cat_data.Home_Ownership.count()
# Out:
# 2499

# %%
cat_data.Home_Ownership.value_counts()
# Out:
# Home_Ownership
# MORTGAGE    1147
# RENT        1146
# OWN          200
# OTHER          5
# NONE           1
# Name: count, dtype: int64

# %%
cat_data.loc[cat_data['Home_Ownership'] == None]
# Out:
# Empty DataFrame
# Columns: [Loan_Purpose, States, Home_Ownership, Loan_id]
# Index: []

# %%
s = pd.Series(cat_data.Home_Ownership.isna())
s[s == True]
# Out:
# 2492    True
# Name: Home_Ownership, dtype: bool

# %%
cat_data.loc[2492,]
# Out:
# Loan_Purpose      debt_consolidation
# States                            NJ
# Home_Ownership                   NaN
# Loan_id                         2493
# Name: 2492, dtype: object

# %%
cat_data['Home_Ownership']  = cat_data['Home_Ownership'].replace("NaN",None)
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_1252\2801747167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['Home_Ownership']  = cat_data['Home_Ownership'].replace("NaN",None)

# %%
cat_data.Home_Ownership.value_counts()
# Out:
# Home_Ownership
# MORTGAGE    1147
# RENT        1146
# OWN          200
# OTHER          5
# NONE           1
# Name: count, dtype: int64

# %%
cat_data.isna().sum()
# Out:
# Loan_Purpose      0
# States            0
# Home_Ownership    1
# Loan_id           0
# dtype: int64

# %%
cat_data.tail(10)
# Out:
#             Loan_Purpose States Home_Ownership  Loan_id
# 2490  debt_consolidation     CA           RENT     2491
# 2491  debt_consolidation     CA           RENT     2492
# 2492  debt_consolidation     NJ            NaN     2493
# 2493               other     IL       MORTGAGE     2494
# 2494  debt_consolidation     WA       MORTGAGE     2495
# 2495  debt_consolidation     NY       MORTGAGE     2496
# 2496    home_improvement     MD            OWN     2497
# 2497  debt_consolidation     PA       MORTGAGE     2498
# 2498      major_purchase     NJ           RENT     2499
# 2499  debt_consolidation     NY           RENT     2500

# %%
cat_data = cat_data.drop(2492)

# %%
cat_data.isna().sum()
# Out:
# Loan_Purpose      0
# States            0
# Home_Ownership    0
# Loan_id           0
# dtype: int64

# %%
cat_data.shape
# Out:
# (2499, 4)

# %%
num_data = num_data.drop(2492)

# %%
num_data.shape
# Out:
# (2499, 12)

# %% [markdown]
#  fOR MERGING THE TWO DATASETS , There should be a common column.

# %%
cat_data.head(2)
# Out:
#          Loan_Purpose States Home_Ownership  Loan_id
# 0  debt_consolidation     SC       MORTGAGE        1
# 1  debt_consolidation     TX       MORTGAGE        2

# %%
num_data.head(2)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               14.0                   14272.0
# 1               12.0                   11140.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                             2.0                1.0
# 1                             1.0                2.0

# %% [markdown]
# .

# %% [markdown]
# # Outlier Treatment

# %%
num_data.head()
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
# 2        3           35000.0                     35000.0          21.98
# 3        4           10000.0                      9975.0           9.99
# 4        5           12000.0                     12000.0          11.71
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
# 2         60.0                 23.81        11500.00       690.0
# 3         36.0                 14.30         3833.33       695.0
# 4         36.0                 18.78         3195.00       695.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               14.0                   14272.0
# 1               12.0                   11140.0
# 2               14.0                   21977.0
# 3               10.0                    9346.0
# 4               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                             2.0                1.0
# 1                             1.0                2.0
# 2                             1.0                2.0
# 3                             0.0                5.0
# 4                             0.0                9.0

# %% [markdown]
# **Just observing a single column for the outliers:**

# %%
num_data.describe()
# Out:
#            Loan_id  Amount_Requested  Amount_Funded_By_Investors  \
# count  2499.000000       2499.000000                  2499.00000
# mean   1250.002801      12406.902761                 12003.83477
# std     721.548325       7802.156772                  7746.04527
# min       1.000000       1000.000000                    -0.01000
# 25%     625.500000       6000.000000                  6000.00000
# 50%    1250.000000      10000.000000                 10000.00000
# 75%    1874.500000      17000.000000                 16000.00000
# max    2500.000000      35000.000000                 35000.00000
#
#        Interest_Rate  Loan_Length  Debt_To_Income_Ratio  Monthly_Income  \
# count    2499.000000  2499.000000           2499.000000     2499.000000
# mean       13.066619    41.262905             15.380420     5688.864626
# std         4.175938     9.932322              7.505052     3963.128380
# min         5.420000    36.000000              0.000000      588.500000
# 25%        10.160000    36.000000              9.750000     3500.000000
# 50%        13.110000    36.000000             15.320000     5000.000000
# 75%        15.800000    36.000000             20.675000     6800.000000
# max        24.890000    60.000000             34.910000   102750.000000
#
#         FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# count  2499.000000        2499.000000               2499.000000
# mean    705.898359          10.073629              15221.817127
# std      35.035486           4.504621              18273.326539
# min     640.000000           2.000000                  0.000000
# 25%     680.000000           7.000000               5587.500000
# 50%     700.000000           9.000000              10948.000000
# 75%     725.000000          13.000000              18849.500000
# max     830.000000          38.000000             270800.000000
#
#        Inquiries_in_the_Last_6_Months  Employment_Length
# count                     2499.000000         2499.00000
# mean                         0.905162            5.47499
# std                          1.230862            3.38905
# min                          0.000000            1.00000
# 25%                          0.000000            2.00000
# 50%                          0.000000            5.00000
# 75%                          1.000000           10.00000
# max                          9.000000           10.00000

# %%
min_Amt = num_data.Amount_Requested.min()
min_Amt
# Out:
# 1000.0

# %%
max_Amt = num_data.Amount_Requested.max()
max_Amt
# Out:
# 35000.0

# %% [markdown]
# **quantile() helps to find the percentile vaues at each percentile mark.**

# %%
median = num_data.Amount_Requested.quantile(0.5)
median
# Out:
# 10000.0

# %%
f_q = num_data.Amount_Requested.quantile(0.25)
t_q = num_data.Amount_Requested.quantile(0.75)
p_1 = num_data.Amount_Requested.quantile(0.01)
p_99 = num_data.Amount_Requested.quantile(0.99)

# %%
print("First quartile:",f_q)
print("Third quartile:",t_q)
print("Bottom 1%ile cutoff:",p_1)
print("Top 1%ile cutoff:",p_99)
# Out:
# First quartile: 6000.0
# Third quartile: 17000.0
# Bottom 1%ile cutoff: 1500.0
# Top 1%ile cutoff: 35000.0

# %%
#iqr = q3 - q1
iqr = 17000 - 6000

# %%
iqr
# Out:
# 11000

# %%
#lc = q1 - 1.5*iqr
#uc = q3 + 1.5*iqr

# %%
lc = 6000 - (1.5*iqr)
lc
# Out:
# -10500.0

# %%
uc = 17000 + (1.5*iqr)
uc
# Out:
# 33500.0

# %%
sns.boxplot(num_data.Amount_Requested)
# Out:
# <Axes: >

# %%
num_data.head()
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
# 2        3           35000.0                     35000.0          21.98
# 3        4           10000.0                      9975.0           9.99
# 4        5           12000.0                     12000.0          11.71
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
# 2         60.0                 23.81        11500.00       690.0
# 3         36.0                 14.30         3833.33       695.0
# 4         36.0                 18.78         3195.00       695.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               14.0                   14272.0
# 1               12.0                   11140.0
# 2               14.0                   21977.0
# 3               10.0                    9346.0
# 4               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                             2.0                1.0
# 1                             1.0                2.0
# 2                             1.0                2.0
# 3                             0.0                5.0
# 4                             0.0                9.0

# %%
num_data.Loan_Length.nunique()
# Out:
# 2

# %%
num_data.Loan_Length.value_counts()
# Out:
# Loan_Length
# 36.0    1951
# 60.0     548
# Name: count, dtype: int64

# %%
num_data.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
num_data.Inquiries_in_the_Last_6_Months.value_counts()
# Out:
# Inquiries_in_the_Last_6_Months
# 0.0    1252
# 1.0     657
# 2.0     335
# 3.0     169
# 4.0      50
# 5.0      14
# 6.0       8
# 7.0       7
# 9.0       5
# 8.0       2
# Name: count, dtype: int64

# %%
for col in num_data:
    sns.boxplot(num_data[col])
    plt.show()

# %%
num_data2  = num_data.copy()
#num_data3 = num_data.copy()

# %%
num_data2
# Out:
#       Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0           1           20000.0                    20000.00           8.90
# 1           2           19200.0                    19200.00          12.12
# 2           3           35000.0                    35000.00          21.98
# 3           4           10000.0                     9975.00           9.99
# 4           5           12000.0                    12000.00          11.71
# ...       ...               ...                         ...            ...
# 2495     2496           30000.0                    29950.00          16.77
# 2496     2497           16000.0                    16000.00          14.09
# 2497     2498           10000.0                    10000.00          13.99
# 2498     2499            6000.0                     6000.00          12.42
# 2499     2500            9000.0                     5242.75          13.79
#
#       Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0            36.0                 14.90         6541.67       735.0
# 1            36.0                 28.36         4583.33       715.0
# 2            60.0                 23.81        11500.00       690.0
# 3            36.0                 14.30         3833.33       695.0
# 4            36.0                 18.78         3195.00       695.0
# ...           ...                   ...             ...         ...
# 2495         60.0                 19.23         9250.00       705.0
# 2496         60.0                 21.54         8903.25       740.0
# 2497         36.0                  4.89         2166.67       680.0
# 2498         36.0                 16.66         3500.00       675.0
# 2499         36.0                  6.76         3875.00       670.0
#
#       Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0                  14.0                   14272.0
# 1                  12.0                   11140.0
# 2                  14.0                   21977.0
# 3                  10.0                    9346.0
# 4                  11.0                   14469.0
# ...                 ...                       ...
# 2495               15.0                   45880.0
# 2496               18.0                   18898.0
# 2497                4.0                    4544.0
# 2498                8.0                    7753.0
# 2499                7.0                    7589.0
#
#       Inquiries_in_the_Last_6_Months  Employment_Length
# 0                                2.0                1.0
# 1                                1.0                2.0
# 2                                1.0                2.0
# 3                                0.0                5.0
# 4                                0.0                9.0
# ...                              ...                ...
# 2495                             1.0                8.0
# 2496                             1.0               10.0
# 2497                             0.0               10.0
# 2498                             0.0                5.0
# 2499                             0.0               10.0
#
# [2499 rows x 12 columns]

# %%
lc
# Out:
# -10500.0

# %%
uc
# Out:
# 33500.0

# %%
#Outliers have been clipped.
num_data2['Amount_Requested'] = num_data2.Amount_Requested.clip(lower = lc, upper = uc)

# %%
sns.boxplot(num_data.Amount_Requested)
# Out:
# <Axes: >

# %%
sns.boxplot(num_data2.Amount_Requested)
# Out:
# <Axes: >

# %%
num_data.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
sns.boxplot(num_data2.Amount_Funded_By_Investors)
# Out:
# <Axes: >

# %%
num_data2['Amount_Requested'] = num_data2.Amount_Funded_By_Investors.clip(lower = lc, upper = uc)

# %% [markdown]
# **The variables on which we have to put the outliers are**

# %% [markdown]
# # Outlier treatment IQR Method

# %%
def outlier_IQR(s):
    m = s.quantile(0.5)
    q1 = s.quantile(0.25)
    q3 = s.quantile(0.75)
    q_1p = s.quantile(0.01)
    q_99p = s.quantile(0.99)
    iqr = q3 - q1
    lc = q1 - 1.5*iqr
    uc = q3 + 1.5*iqr
    result = pd.Series([m,q1,q3,q_1p,q_99p,iqr,lc,uc])
    result.index = ['median','first_quartile','third_quartile','pc_1','pc_99','iqr','lower_cutoff','upper_cutoff']
    return result

# %%
def outliertreat_IQR(d):
    m = d.quantile(0.5)
    q1 = d.quantile(0.25)
    q3 = d.quantile(0.75)
    q_1p = d.quantile(0.01)
    q_99p = d.quantile(0.99)
    iqr = q3 - q1
    lc = q1 - 1.5*iqr
    uc = q3 + 1.5*iqr
    return lc,uc

# %%
num_data.apply(outliertreat_IQR)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0  -1248.0          -10500.0                     -9000.0           1.70
# 1   3748.0           33500.0                     31000.0          24.26
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0               -6.6375         -1450.0       612.5
# 1         36.0               37.0625         11750.0       792.5
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               -2.0                  -14305.5
# 1               22.0                   38742.5
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                            -1.5              -10.0
# 1                             2.5               22.0

# %%
num_data2.apply(outlier_IQR)
# Out:
#                 Loan_id  Amount_Requested  Amount_Funded_By_Investors  \
# median          1250.00        10000.0000                  10000.0000
# first_quartile   625.50         6000.0000                   6000.0000
# third_quartile  1874.50        16000.0000                  16000.0000
# pc_1              25.98          998.3456                    998.3456
# pc_99           2474.02        33500.0000                  35000.0000
# iqr             1249.00        10000.0000                  10000.0000
# lower_cutoff   -1248.00        -9000.0000                  -9000.0000
# upper_cutoff    3748.00        31000.0000                  31000.0000
#
#                 Interest_Rate  Loan_Length  Debt_To_Income_Ratio  \
# median                13.1100         36.0               15.3200
# first_quartile        10.1600         36.0                9.7500
# third_quartile        15.8000         36.0               20.6750
# pc_1                   5.9860         36.0                0.7180
# pc_99                 22.9566         60.0               33.2300
# iqr                    5.6400          0.0               10.9250
# lower_cutoff           1.7000         36.0               -6.6375
# upper_cutoff          24.2600         36.0               37.0625
#
#                 Monthly_Income  FICO_Range  Open_CREDIT_Lines  \
# median               5000.0000       700.0                9.0
# first_quartile       3500.0000       680.0                7.0
# third_quartile       6800.0000       725.0               13.0
# pc_1                 1416.4032       660.0                3.0
# pc_99               18750.0000       805.0               23.0
# iqr                  3300.0000        45.0                6.0
# lower_cutoff        -1450.0000       612.5               -2.0
# upper_cutoff        11750.0000       792.5               22.0
#
#                 Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  \
# median                          10948.00                             0.0
# first_quartile                   5587.50                             0.0
# third_quartile                  18849.50                             1.0
# pc_1                                0.00                             0.0
# pc_99                           92416.32                             5.0
# iqr                             13262.00                             1.0
# lower_cutoff                   -14305.50                            -1.5
# upper_cutoff                    38742.50                             2.5
#
#                 Employment_Length
# median                        5.0
# first_quartile                2.0
# third_quartile               10.0
# pc_1                          1.0
# pc_99                        10.0
# iqr                           8.0
# lower_cutoff                -10.0
# upper_cutoff                 22.0

# %%
cutoffs = pd.DataFrame(num_data2.apply(outliertreat_IQR))
cutoffs
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0  -1248.0           -9000.0                     -9000.0           1.70
# 1   3748.0           31000.0                     31000.0          24.26
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0               -6.6375         -1450.0       612.5
# 1         36.0               37.0625         11750.0       792.5
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               -2.0                  -14305.5
# 1               22.0                   38742.5
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                            -1.5              -10.0
# 1                             2.5               22.0

# %% [markdown]
# Made two copies of numerical data and will make two models on each of them and will decide later which one is giving better predictiona and minimum RMSPE OR MAPE error.

# %%
num_data_2a = num_data.copy()
num_data_2b = num_data.copy()

# %% [markdown]
# # Outlier treatment of only required columns:

# %%
num_data_2a.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
for col in num_data2:
    sns.boxplot(num_data2[col])
    plt.show()

# %%
num_data2.Inquiries_in_the_Last_6_Months.value_counts()
# Out:
# Inquiries_in_the_Last_6_Months
# 0.0    1252
# 1.0     657
# 2.0     335
# 3.0     169
# 4.0      50
# 5.0      14
# 6.0       8
# 7.0       7
# 9.0       5
# 8.0       2
# Name: count, dtype: int64

# %%
l = ['Amount_Requested','Amount_Funded_By_Investors','Interest_rate','FICO_Range','Open_CREDIT_Lines','Inquiries_in_the_Last_6_Months']

# %%
num_data.apply(outliertreat_IQR)
#num_data2['Amount_Requested'] = num_data2.Amount_Funded_By_Investors.clip(lower = lc, upper = uc)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0  -1248.0          -10500.0                     -9000.0           1.70
# 1   3748.0           33500.0                     31000.0          24.26
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0               -6.6375         -1450.0       612.5
# 1         36.0               37.0625         11750.0       792.5
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               -2.0                  -14305.5
# 1               22.0                   38742.5
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                            -1.5              -10.0
# 1                             2.5               22.0

# %% [markdown]
# Amount Requested

# %%
num_data_2a['Amount_Requested'] = num_data_2a.Amount_Requested.clip(lower = -10500.00, upper = 33500)

# %%
sns.boxplot(num_data_2a.Amount_Requested)
# Out:
# <Axes: >

# %% [markdown]
# Amount_Funded_By_Investors

# %%
num_data_2a['Amount_Funded_By_Investors'] = num_data_2a.Amount_Funded_By_Investors.clip(lower = -9000, upper = 31000)
sns.boxplot(num_data_2a.Amount_Requested)
# Out:
# <Axes: >

# %%
num_data_2a['Interest Rate'] = num_data_2a.Interest_Rate.clip(lower = 1.70, upper = 24.26)
sns.boxplot(num_data_2a.Interest_Rate)
# Out:
# <Axes: >

# %% [markdown]
# FICO_Range

# %%
num_data_2a['FICO_Range'] = num_data_2a.FICO_Range.clip(lower = 612.5, upper = 792.5)
sns.boxplot(num_data_2a.FICO_Range)
# Out:
# <Axes: >

# %% [markdown]
# Open_CREDIT_Lines

# %%
num_data_2a['Open_CREDIT_Lines'] = num_data_2a.Open_CREDIT_Lines.clip(lower = -2.0, upper = 22.0)
sns.boxplot(num_data_2a.Open_CREDIT_Lines)
# Out:
# <Axes: >

# %% [markdown]
# Inquiries_in_the_Last_6_Months

# %%
num_data_2a['Inquiries_in_the_Last_6_Months'] = num_data_2a.Inquiries_in_the_Last_6_Months.clip(lower = -1.5, upper = 2.5)
sns.boxplot(num_data_2a.Inquiries_in_the_Last_6_Months)
# Out:
# <Axes: >

# %%
num_data_2a
# Out:
#       Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0           1           20000.0                    20000.00           8.90
# 1           2           19200.0                    19200.00          12.12
# 2           3           33500.0                    31000.00          21.98
# 3           4           10000.0                     9975.00           9.99
# 4           5           12000.0                    12000.00          11.71
# ...       ...               ...                         ...            ...
# 2495     2496           30000.0                    29950.00          16.77
# 2496     2497           16000.0                    16000.00          14.09
# 2497     2498           10000.0                    10000.00          13.99
# 2498     2499            6000.0                     6000.00          12.42
# 2499     2500            9000.0                     5242.75          13.79
#
#       Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0            36.0                 14.90         6541.67       735.0
# 1            36.0                 28.36         4583.33       715.0
# 2            60.0                 23.81        11500.00       690.0
# 3            36.0                 14.30         3833.33       695.0
# 4            36.0                 18.78         3195.00       695.0
# ...           ...                   ...             ...         ...
# 2495         60.0                 19.23         9250.00       705.0
# 2496         60.0                 21.54         8903.25       740.0
# 2497         36.0                  4.89         2166.67       680.0
# 2498         36.0                 16.66         3500.00       675.0
# 2499         36.0                  6.76         3875.00       670.0
#
#       Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0                  14.0                   14272.0
# 1                  12.0                   11140.0
# 2                  14.0                   21977.0
# 3                  10.0                    9346.0
# 4                  11.0                   14469.0
# ...                 ...                       ...
# 2495               15.0                   45880.0
# 2496               18.0                   18898.0
# 2497                4.0                    4544.0
# 2498                8.0                    7753.0
# 2499                7.0                    7589.0
#
#       Inquiries_in_the_Last_6_Months  Employment_Length  Interest Rate
# 0                                2.0                1.0           8.90
# 1                                1.0                2.0          12.12
# 2                                1.0                2.0          21.98
# 3                                0.0                5.0           9.99
# 4                                0.0                9.0          11.71
# ...                              ...                ...            ...
# 2495                             1.0                8.0          16.77
# 2496                             1.0               10.0          14.09
# 2497                             0.0               10.0          13.99
# 2498                             0.0                5.0          12.42
# 2499                             0.0               10.0          13.79
#
# [2499 rows x 13 columns]

# %% [markdown]
# **Outlier treatment on all columns in num_data_2b**

# %%
num_data_2b.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
num_data_2b.head()
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
# 2        3           35000.0                     35000.0          21.98
# 3        4           10000.0                      9975.0           9.99
# 4        5           12000.0                     12000.0          11.71
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
# 2         60.0                 23.81        11500.00       690.0
# 3         36.0                 14.30         3833.33       695.0
# 4         36.0                 18.78         3195.00       695.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               14.0                   14272.0
# 1               12.0                   11140.0
# 2               14.0                   21977.0
# 3               10.0                    9346.0
# 4               11.0                   14469.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                             2.0                1.0
# 1                             1.0                2.0
# 2                             1.0                2.0
# 3                             0.0                5.0
# 4                             0.0                9.0

# %%
num_data_2b.Amount_Requested.quantile(0.25)
# Out:
# 6000.0

# %%
for col in num_data_2b.columns:
    q1 = num_data_2b[col].quantile(0.25)
    q3 = num_data_2b[col].quantile(0.75)
    iqr = q3 - q1
    lc = q1 - 1.5*iqr
    uc = q3 + 1.5*iqr
    num_data_2b[col] = num_data_2b[col].clip(lower = lc, upper = uc)

# %%
for col in num_data_2b:
    sns.boxplot(num_data_2b[col])
    plt.show()

# %%
num_data_2a.head(2)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               14.0                   14272.0
# 1               12.0                   11140.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length  Interest Rate
# 0                             2.0                1.0           8.90
# 1                             1.0                2.0          12.12

# %%
num_data_2a.shape
# Out:
# (2499, 13)

# %%
num_data_2a = num_data_2a.drop(columns = 'Interest Rate')

# %%
num_data_2a.shape
# Out:
# (2499, 12)

# %%
num_data_2b.shape
# Out:
# (2499, 12)

# %%
num_data_2a.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
num_data_2b.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
num_data_2b.head(2)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0               14.0                   14272.0
# 1               12.0                   11140.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length
# 0                             2.0                1.0
# 1                             1.0                2.0

# %%
num_data_2b.shape
# Out:
# (2499, 12)

# %%
cat_data.head(2)
# Out:
#          Loan_Purpose States Home_Ownership  Loan_id
# 0  debt_consolidation     SC       MORTGAGE        1
# 1  debt_consolidation     TX       MORTGAGE        2

# %% [markdown]
# .

# %% [markdown]
# # Merging the categorical and the numerical data to get the dataset:

# %%
#cat_data['Loan_ID'] = data['LoanID']
#cat_data

# %%
M_data1 = pd.merge(num_data_2a,cat_data,how = 'inner',left_on = 'Loan_id',right_on = 'Loan_id')

# %%
M_data1.shape
# Out:
# (2499, 15)

# %%
M_data1.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length', 'Loan_Purpose', 'States', 'Home_Ownership'],
#       dtype='object')

# %%
M_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Loan_id                         2499 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2499 non-null   float64
#  4   Loan_Length                     2499 non-null   float64
#  5   Debt_To_Income_Ratio            2499 non-null   float64
#  6   Monthly_Income                  2499 non-null   float64
#  7   FICO_Range                      2499 non-null   float64
#  8   Open_CREDIT_Lines               2499 non-null   float64
#  9   Revolving_CREDIT_Balance        2499 non-null   float64
#  10  Inquiries_in_the_Last_6_Months  2499 non-null   float64
#  11  Employment_Length               2499 non-null   float64
#  12  Loan_Purpose                    2499 non-null   object
#  13  States                          2499 non-null   object
#  14  Home_Ownership                  2499 non-null   object
# dtypes: float64(11), int64(1), object(3)
# memory usage: 293.0+ KB

# %%
M_data2 = pd.merge(num_data_2b,cat_data,how = 'inner',left_on = 'Loan_id',right_on = 'Loan_id')

# %%
M_data2.shape
# Out:
# (2499, 15)

# %%
M_data2.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length', 'Loan_Purpose', 'States', 'Home_Ownership'],
#       dtype='object')

# %% [markdown]
# .

# %% [markdown]
# # One-Hot Encoding: Conversion of categorical variables to continuous variables.

# %%
M_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Loan_id                         2499 non-null   int64
#  1   Amount_Requested                2499 non-null   float64
#  2   Amount_Funded_By_Investors      2499 non-null   float64
#  3   Interest_Rate                   2499 non-null   float64
#  4   Loan_Length                     2499 non-null   float64
#  5   Debt_To_Income_Ratio            2499 non-null   float64
#  6   Monthly_Income                  2499 non-null   float64
#  7   FICO_Range                      2499 non-null   float64
#  8   Open_CREDIT_Lines               2499 non-null   float64
#  9   Revolving_CREDIT_Balance        2499 non-null   float64
#  10  Inquiries_in_the_Last_6_Months  2499 non-null   float64
#  11  Employment_Length               2499 non-null   float64
#  12  Loan_Purpose                    2499 non-null   object
#  13  States                          2499 non-null   object
#  14  Home_Ownership                  2499 non-null   object
# dtypes: float64(11), int64(1), object(3)
# memory usage: 293.0+ KB

# %%
M_data1.Loan_Purpose.nunique()
# Out:
# 14

# %%
#M_data1.State.nunique()

# %%
M_data1.Home_Ownership.nunique()
# Out:
# 5

# %%
M_data1a = M_data1.copy()

# %%
#M_data1a = M_data1a.drop(columns = 'State')

# %%
M_data1a.shape
# Out:
# (2499, 15)

# %%
M_data2a = M_data2.copy()

# %%
#M_data2a = M_data2a.drop(columns = 'State')

# %%
M_data2a.shape
# Out:
# (2499, 15)

# %%
M_data1a = pd.get_dummies(M_data1a,columns = ['Home_Ownership','Loan_Purpose'])

# %%
M_data1a.head(5)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
# 2        3           33500.0                     31000.0          21.98
# 3        4           10000.0                      9975.0           9.99
# 4        5           12000.0                     12000.0          11.71
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
# 2         60.0                 23.81        11500.00       690.0
# 3         36.0                 14.30         3833.33       695.0
# 4         36.0                 18.78         3195.00       695.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  ...  \
# 0               14.0                   14272.0  ...
# 1               12.0                   11140.0  ...
# 2               14.0                   21977.0  ...
# 3               10.0                    9346.0  ...
# 4               11.0                   14469.0  ...
#
#    Loan_Purpose_home_improvement  Loan_Purpose_house  \
# 0                          False               False
# 1                          False               False
# 2                          False               False
# 3                          False               False
# 4                          False               False
#
#   Loan_Purpose_major_purchase  Loan_Purpose_medical  Loan_Purpose_moving  \
# 0                       False                 False                False
# 1                       False                 False                False
# 2                       False                 False                False
# 3                       False                 False                False
# 4                       False                 False                False
#
#    Loan_Purpose_other  Loan_Purpose_renewable_energy  \
# 0               False                          False
# 1               False                          False
# 2               False                          False
# 3               False                          False
# 4               False                          False
#
#    Loan_Purpose_small_business  Loan_Purpose_vacation  Loan_Purpose_wedding
# 0                        False                  False                 False
# 1                        False                  False                 False
# 2                        False                  False                 False
# 3                        False                  False                 False
# 4                        False                  False                 False
#
# [5 rows x 32 columns]

# %%
M_data1a.shape
# Out:
# (2499, 32)

# %%
M_data1a.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length', 'States', 'Home_Ownership_MORTGAGE',
#        'Home_Ownership_NONE', 'Home_Ownership_OTHER', 'Home_Ownership_OWN',
#        'Home_Ownership_RENT', 'Loan_Purpose_car', 'Loan_Purpose_credit_card',
#        'Loan_Purpose_debt_consolidation', 'Loan_Purpose_educational',
#        'Loan_Purpose_home_improvement', 'Loan_Purpose_house',
#        'Loan_Purpose_major_purchase', 'Loan_Purpose_medical',
#        'Loan_Purpose_moving', 'Loan_Purpose_other',
#        'Loan_Purpose_renewable_energy', 'Loan_Purpose_small_business',
#        'Loan_Purpose_vacation', 'Loan_Purpose_wedding'],
#       dtype='object')

# %%
M_data2a = pd.get_dummies(M_data2a,columns = ['Home_Ownership','Loan_Purpose'])
M_data2a.head(5)
# Out:
#    Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0        1           20000.0                     20000.0           8.90
# 1        2           19200.0                     19200.0          12.12
# 2        3           33500.0                     31000.0          21.98
# 3        4           10000.0                      9975.0           9.99
# 4        5           12000.0                     12000.0          11.71
#
#    Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0         36.0                 14.90         6541.67       735.0
# 1         36.0                 28.36         4583.33       715.0
# 2         36.0                 23.81        11500.00       690.0
# 3         36.0                 14.30         3833.33       695.0
# 4         36.0                 18.78         3195.00       695.0
#
#    Open_CREDIT_Lines  Revolving_CREDIT_Balance  ...  \
# 0               14.0                   14272.0  ...
# 1               12.0                   11140.0  ...
# 2               14.0                   21977.0  ...
# 3               10.0                    9346.0  ...
# 4               11.0                   14469.0  ...
#
#    Loan_Purpose_home_improvement  Loan_Purpose_house  \
# 0                          False               False
# 1                          False               False
# 2                          False               False
# 3                          False               False
# 4                          False               False
#
#   Loan_Purpose_major_purchase  Loan_Purpose_medical  Loan_Purpose_moving  \
# 0                       False                 False                False
# 1                       False                 False                False
# 2                       False                 False                False
# 3                       False                 False                False
# 4                       False                 False                False
#
#    Loan_Purpose_other  Loan_Purpose_renewable_energy  \
# 0               False                          False
# 1               False                          False
# 2               False                          False
# 3               False                          False
# 4               False                          False
#
#    Loan_Purpose_small_business  Loan_Purpose_vacation  Loan_Purpose_wedding
# 0                        False                  False                 False
# 1                        False                  False                 False
# 2                        False                  False                 False
# 3                        False                  False                 False
# 4                        False                  False                 False
#
# [5 rows x 32 columns]

# %%
M_data1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Loan_id                          2499 non-null   int64
#  1   Amount_Requested                 2499 non-null   float64
#  2   Amount_Funded_By_Investors       2499 non-null   float64
#  3   Interest_Rate                    2499 non-null   float64
#  4   Loan_Length                      2499 non-null   float64
#  5   Debt_To_Income_Ratio             2499 non-null   float64
#  6   Monthly_Income                   2499 non-null   float64
#  7   FICO_Range                       2499 non-null   float64
#  8   Open_CREDIT_Lines                2499 non-null   float64
#  9   Revolving_CREDIT_Balance         2499 non-null   float64
#  10  Inquiries_in_the_Last_6_Months   2499 non-null   float64
#  11  Employment_Length                2499 non-null   float64
#  12  States                           2499 non-null   object
#  13  Home_Ownership_MORTGAGE          2499 non-null   bool
#  14  Home_Ownership_NONE              2499 non-null   bool
#  15  Home_Ownership_OTHER             2499 non-null   bool
#  16  Home_Ownership_OWN               2499 non-null   bool
#  17  Home_Ownership_RENT              2499 non-null   bool
#  18  Loan_Purpose_car                 2499 non-null   bool
#  19  Loan_Purpose_credit_card         2499 non-null   bool
#  20  Loan_Purpose_debt_consolidation  2499 non-null   bool
#  21  Loan_Purpose_educational         2499 non-null   bool
#  22  Loan_Purpose_home_improvement    2499 non-null   bool
#  23  Loan_Purpose_house               2499 non-null   bool
#  24  Loan_Purpose_major_purchase      2499 non-null   bool
#  25  Loan_Purpose_medical             2499 non-null   bool
#  26  Loan_Purpose_moving              2499 non-null   bool
#  27  Loan_Purpose_other               2499 non-null   bool
#  28  Loan_Purpose_renewable_energy    2499 non-null   bool
#  29  Loan_Purpose_small_business      2499 non-null   bool
#  30  Loan_Purpose_vacation            2499 non-null   bool
#  31  Loan_Purpose_wedding             2499 non-null   bool
# dtypes: bool(19), float64(11), int64(1), object(1)
# memory usage: 300.3+ KB

# %% [markdown]
# .

# %% [markdown]
# # Logarithmic Transformations

# %% [markdown]
# #To convert a data distribution into a normal distribution curve, we can apply various types of transformations on the data:
# #Logarithmic, Exponential, Sqquare, Cube, sqrt, cbrt etc.

# %%
sns.displot(num_data.Interest_Rate,kde = True)
#kde is actually an operator which provides a curve to the histograms and aslo defines the function of the curve.
# Out:
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(np.log(num_data.Interest_Rate),kde = True)
# Out:
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#sns.displot(np.square(num_data.Interest_Rate),kde = True)

# %% [markdown]
# Check all the variables distribution after logarithmic transformation.

# %%
for col in M_data1a.columns:
    sns.displot(M_data1a[col],kde = True)
# Out:
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:447: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for col in M_data1a.columns:
    sns.displot(np.log(M_data1a[col]),kde = True)
# Out:
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 2
#       1 for col in M_data1a.columns:
# ----> 2     sns.displot(np.log(M_data1a[col]),kde = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2016, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2012 @final
#    2013 def __array_ufunc__(
#    2014     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2015 ):
# -> 2016     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     393 elif self.ndim == 1:
#     394     # ufunc(series, ...)
#     395     inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 396     result = getattr(ufunc, method)(*inputs, **kwargs)
#     397 else:
#     398     # ufunc(dataframe)
#     399     if method == "__call__" and not kwargs:
#     400         # for np.<ufunc>(..) calls
#     401         # kwargs cannot necessarily be handled block-by-block, so only
#     402         # take this path if there are no kwargs
#
# TypeError: loop of ufunc does not support argument 0 of type str which has no callable log method

# %% [markdown]
# .

# %% [markdown]
# # Standardisation of the numerical data

# %%
from scipy import stats

# %%
num_data
# Out:
#       Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0           1           20000.0                    20000.00           8.90
# 1           2           19200.0                    19200.00          12.12
# 2           3           35000.0                    35000.00          21.98
# 3           4           10000.0                     9975.00           9.99
# 4           5           12000.0                    12000.00          11.71
# ...       ...               ...                         ...            ...
# 2495     2496           30000.0                    29950.00          16.77
# 2496     2497           16000.0                    16000.00          14.09
# 2497     2498           10000.0                    10000.00          13.99
# 2498     2499            6000.0                     6000.00          12.42
# 2499     2500            9000.0                     5242.75          13.79
#
#       Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0            36.0                 14.90         6541.67       735.0
# 1            36.0                 28.36         4583.33       715.0
# 2            60.0                 23.81        11500.00       690.0
# 3            36.0                 14.30         3833.33       695.0
# 4            36.0                 18.78         3195.00       695.0
# ...           ...                   ...             ...         ...
# 2495         60.0                 19.23         9250.00       705.0
# 2496         60.0                 21.54         8903.25       740.0
# 2497         36.0                  4.89         2166.67       680.0
# 2498         36.0                 16.66         3500.00       675.0
# 2499         36.0                  6.76         3875.00       670.0
#
#       Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0                  14.0                   14272.0
# 1                  12.0                   11140.0
# 2                  14.0                   21977.0
# 3                  10.0                    9346.0
# 4                  11.0                   14469.0
# ...                 ...                       ...
# 2495               15.0                   45880.0
# 2496               18.0                   18898.0
# 2497                4.0                    4544.0
# 2498                8.0                    7753.0
# 2499                7.0                    7589.0
#
#       Inquiries_in_the_Last_6_Months  Employment_Length
# 0                                2.0                1.0
# 1                                1.0                2.0
# 2                                1.0                2.0
# 3                                0.0                5.0
# 4                                0.0                9.0
# ...                              ...                ...
# 2495                             1.0                8.0
# 2496                             1.0               10.0
# 2497                             0.0               10.0
# 2498                             0.0                5.0
# 2499                             0.0               10.0
#
# [2499 rows x 12 columns]

# %%
num_data_z = num_data.apply(stats.zscore)   #STANDARDISATION OF THE DATA

# %%
num_data_z
# Out:
#        Loan_id  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0    -1.731350          0.973400                    1.032497      -0.997968
# 1    -1.729964          0.870843                    0.929197      -0.226729
# 2    -1.728578          2.896330                    2.969356       2.134889
# 3    -1.727192         -0.308554                   -0.261971      -0.736897
# 4    -1.725805         -0.052163                   -0.000495      -0.324931
# ...        ...               ...                         ...            ...
# 2495  1.727184          2.255353                    2.317280       0.887016
# 2496  1.728570          0.460618                    0.516001       0.245115
# 2497  1.729956         -0.308554                   -0.258743       0.221164
# 2498  1.731342         -0.821335                   -0.775239      -0.154875
# 2499  1.732729         -0.436749                   -0.873018       0.173261
#
#       Loan_Length  Debt_To_Income_Ratio  Monthly_Income  FICO_Range  \
# 0       -0.529983             -0.064026        0.215228    0.830800
# 1       -0.529983              1.729792       -0.279011    0.259835
# 2        1.886854              1.123412        1.466594   -0.453870
# 3       -0.529983             -0.143988       -0.468293   -0.311129
# 4       -0.529983              0.453063       -0.629393   -0.311129
# ...           ...                   ...             ...         ...
# 2495     1.886854              0.513034        0.898747   -0.025647
# 2496     1.886854              0.820889        0.811235    0.973541
# 2497    -0.529983             -1.398061       -0.888919   -0.739352
# 2498    -0.529983              0.170530       -0.552418   -0.882093
# 2499    -0.529983             -1.148845       -0.457777   -1.024834
#
#       Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0              0.871806                 -0.051989
# 1              0.427729                 -0.223420
# 2              0.871806                  0.369748
# 3             -0.016349                 -0.321616
# 4              0.205690                 -0.041206
# ...                 ...                       ...
# 2495           1.093845                  1.678092
# 2496           1.759961                  0.201218
# 2497          -1.348581                 -0.584456
# 2498          -0.460426                 -0.408810
# 2499          -0.682465                 -0.417786
#
#       Inquiries_in_the_Last_6_Months  Employment_Length
# 0                           0.889667          -1.320690
# 1                           0.077065          -1.025563
# 2                           0.077065          -1.025563
# 3                          -0.735536          -0.140182
# 4                          -0.735536           1.040325
# ...                              ...                ...
# 2495                        0.077065           0.745199
# 2496                        0.077065           1.335452
# 2497                       -0.735536           1.335452
# 2498                       -0.735536          -0.140182
# 2499                       -0.735536           1.335452
#
# [2499 rows x 12 columns]

# %%
#M_data1a.columns

# %%
M_data1a.shape
# Out:
# (2499, 32)

# %%
M_data1a = M_data1a.drop(columns='Loan_id')

# %%
M_data1a.shape
# Out:
# (2499, 31)

# %%
M_data1a['ln_rate'] = np.log(M_data1a.Interest_Rate)

# %%
M_data1a.head(4)
# Out:
#    Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  Loan_Length  \
# 0           20000.0                     20000.0           8.90         36.0
# 1           19200.0                     19200.0          12.12         36.0
# 2           33500.0                     31000.0          21.98         60.0
# 3           10000.0                      9975.0           9.99         36.0
#
#    Debt_To_Income_Ratio  Monthly_Income  FICO_Range  Open_CREDIT_Lines  \
# 0                 14.90         6541.67       735.0               14.0
# 1                 28.36         4583.33       715.0               12.0
# 2                 23.81        11500.00       690.0               14.0
# 3                 14.30         3833.33       695.0               10.0
#
#    Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  ...  \
# 0                   14272.0                             2.0  ...
# 1                   11140.0                             1.0  ...
# 2                   21977.0                             1.0  ...
# 3                    9346.0                             0.0  ...
#
#    Loan_Purpose_house Loan_Purpose_major_purchase  Loan_Purpose_medical  \
# 0               False                       False                 False
# 1               False                       False                 False
# 2               False                       False                 False
# 3               False                       False                 False
#
#    Loan_Purpose_moving  Loan_Purpose_other  Loan_Purpose_renewable_energy  \
# 0                False               False                          False
# 1                False               False                          False
# 2                False               False                          False
# 3                False               False                          False
#
#    Loan_Purpose_small_business  Loan_Purpose_vacation  Loan_Purpose_wedding  \
# 0                        False                  False                 False
# 1                        False                  False                 False
# 2                        False                  False                 False
# 3                        False                  False                 False
#
#     ln_rate
# 0  2.186051
# 1  2.494857
# 2  3.090133
# 3  2.301585
#
# [4 rows x 32 columns]

# %%
M_data1a_t2 = M_data1a.copy()

# %%
M_data1a_t2 = M_data1a_t2.drop(columns = 'Interest_Rate')

# %%
M_data1a_t2.head()
# Out:
#    Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0           20000.0                     20000.0         36.0
# 1           19200.0                     19200.0         36.0
# 2           33500.0                     31000.0         60.0
# 3           10000.0                      9975.0         36.0
# 4           12000.0                     12000.0         36.0
#
#    Debt_To_Income_Ratio  Monthly_Income  FICO_Range  Open_CREDIT_Lines  \
# 0                 14.90         6541.67       735.0               14.0
# 1                 28.36         4583.33       715.0               12.0
# 2                 23.81        11500.00       690.0               14.0
# 3                 14.30         3833.33       695.0               10.0
# 4                 18.78         3195.00       695.0               11.0
#
#    Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  \
# 0                   14272.0                             2.0
# 1                   11140.0                             1.0
# 2                   21977.0                             1.0
# 3                    9346.0                             0.0
# 4                   14469.0                             0.0
#
#    Employment_Length  ... Loan_Purpose_house  Loan_Purpose_major_purchase  \
# 0                1.0  ...              False                        False
# 1                2.0  ...              False                        False
# 2                2.0  ...              False                        False
# 3                5.0  ...              False                        False
# 4                9.0  ...              False                        False
#
#    Loan_Purpose_medical  Loan_Purpose_moving  Loan_Purpose_other  \
# 0                 False                False               False
# 1                 False                False               False
# 2                 False                False               False
# 3                 False                False               False
# 4                 False                False               False
#
#    Loan_Purpose_renewable_energy  Loan_Purpose_small_business  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
#
#    Loan_Purpose_vacation  Loan_Purpose_wedding   ln_rate
# 0                  False                 False  2.186051
# 1                  False                 False  2.494857
# 2                  False                 False  3.090133
# 3                  False                 False  2.301585
# 4                  False                 False  2.460443
#
# [5 rows x 31 columns]

# %%
M_data1a_t2.shape
# Out:
# (2499, 31)

# %% [markdown]
# .

# %% [markdown]
# Doing the same for the other dataset

# %%
M_data2a.columns
# Out:
# Index(['Loan_id', 'Amount_Requested', 'Amount_Funded_By_Investors',
#        'Interest_Rate', 'Loan_Length', 'Debt_To_Income_Ratio',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length', 'States', 'Home_Ownership_MORTGAGE',
#        'Home_Ownership_NONE', 'Home_Ownership_OTHER', 'Home_Ownership_OWN',
#        'Home_Ownership_RENT', 'Loan_Purpose_car', 'Loan_Purpose_credit_card',
#        'Loan_Purpose_debt_consolidation', 'Loan_Purpose_educational',
#        'Loan_Purpose_home_improvement', 'Loan_Purpose_house',
#        'Loan_Purpose_major_purchase', 'Loan_Purpose_medical',
#        'Loan_Purpose_moving', 'Loan_Purpose_other',
#        'Loan_Purpose_renewable_energy', 'Loan_Purpose_small_business',
#        'Loan_Purpose_vacation', 'Loan_Purpose_wedding'],
#       dtype='object')

# %%
M_data2a = M_data2a.drop(columns='Loan_id')

# %%
M_data2a.shape
# Out:
# (2499, 31)

# %%
M_data2a['ln_rate'] = np.log(M_data2a.Interest_Rate)   # I have added a new column of the logarithmic output values.

# %%
M_data2a_t2 = M_data2a.copy()

# %%
M_data2a_t2 = M_data2a_t2.drop(columns = 'Interest_Rate')

# %%
M_data2a_t2.shape
# Out:
# (2499, 31)

# %% [markdown]
# **M_data1a_t1,M_data2a_t1.....transform only the possible variables**

# %% [markdown]
# .
